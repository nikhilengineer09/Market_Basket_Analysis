# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df=pd.read_csv('retail.csv', encoding= 'unicode_escape')

# %%
 df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom

# %% [markdown]
# # Data Cleaning

# %%
df['Description']=df['Description'].str.strip() #removes unnecessary spaces
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True) #removes duplicates of invoices
df['InvoiceNo']=df['InvoiceNo'].astype('str') # Converts invoice number integer to string.
df=df[~df['InvoiceNo'].str.contains('C')] #Removes all the credit transcations.

# %%
df['Country'].value_counts()  #Gives the total number of transactions from each country.
# Out:
# United Kingdom          487622
# Germany                   9042
# France                    8408
# EIRE                      7894
# Spain                     2485
# Netherlands               2363
# Belgium                   2031
# Switzerland               1967
# Portugal                  1501
# Australia                 1185
# Norway                    1072
# Italy                      758
# Channel Islands            748
# Finland                    685
# Cyprus                     614
# Sweden                     451
# Unspecified                446
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     295
# Hong Kong                  284
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# ...

# %%
basket=(df[df['Country']=='France']
        .groupby(['InvoiceNo', 'Description']) ['Quantity']
        .sum().unstack().reset_index().fillna(0)
        .set_index('InvoiceNo'))

# %%
basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
# ...                             ...                         ...
# 580986                          0.0                         0.0
# 581001                          0.0                         0.0
# 581171                          0.0                         0.0
# 581279                          0.0                         0.0
# 581587                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# ...

# %%
#Encode function will convert my all values above and equal to 1 as 1. and that less than or eqaul to 0 as 0.
def encode(x):
    if (x>=1):
        return 1
    elif (x<=0):
        return 0
    
final=basket.applymap(encode)
final.drop('POSTAGE', inplace=True, axis=1) # To remove 'postage' (item).

# %% [markdown]
# ### Model Training

# %%
# Applying my alogorithm to my dataset.
#use_colnames=True ---> It allows the model to use my column name as item name.
bought_together=apriori(final, min_support=0.05, use_colnames=True)

# %%
rules=association_rules(bought_together, metric='lift', min_threshold=1)

# %%
rules
# Out:
#                                           antecedents  \
# 0                         (ALARM CLOCK BAKELIKE PINK)
# 1                        (ALARM CLOCK BAKELIKE GREEN)
# 2                          (ALARM CLOCK BAKELIKE RED)
# 3                        (ALARM CLOCK BAKELIKE GREEN)
# 4                         (ALARM CLOCK BAKELIKE PINK)
# ..                                                ...
# 81  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
# 82  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 83                      (SET/6 RED SPOTTY PAPER CUPS)
# 84               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 85                    (SET/6 RED SPOTTY PAPER PLATES)
#
#                                           consequents  antecedent support  \
# 0                        (ALARM CLOCK BAKELIKE GREEN)            0.102041
# 1                         (ALARM CLOCK BAKELIKE PINK)            0.096939
# 2                        (ALARM CLOCK BAKELIKE GREEN)            0.094388
# ...

# %% [markdown]
# # Making Predictions

# %%
required=rules[(rules['confidence']>0.7)] 
required
# Out:
#                                           antecedents  \
# 0                         (ALARM CLOCK BAKELIKE PINK)
# 1                        (ALARM CLOCK BAKELIKE GREEN)
# 2                          (ALARM CLOCK BAKELIKE RED)
# 3                        (ALARM CLOCK BAKELIKE GREEN)
# 4                         (ALARM CLOCK BAKELIKE PINK)
# 5                          (ALARM CLOCK BAKELIKE RED)
# 8                      (CHILDRENS CUTLERY DOLLY GIRL)
# 9                        (CHILDRENS CUTLERY SPACEBOY)
# 10                             (DOLLY GIRL LUNCH BOX)
# 38                     (PACK OF 6 SKULL PAPER PLATES)
# 39                       (PACK OF 6 SKULL PAPER CUPS)
# 43                        (PLASTERS IN TIN STRONGMAN)
# 52                         (PLASTERS IN TIN SPACEBOY)
# 62                      (SET/6 RED SPOTTY PAPER CUPS)
# 63               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 64                    (SET/6 RED SPOTTY PAPER PLATES)
# ...

# %%
required2=rules[['support', 'confidence', 'lift']]
required2=required2[required2['support']>0.1]
required2
# Out:
#      support  confidence      lift
# 44  0.102041    0.597015  3.545907
# 45  0.102041    0.606061  3.545907
# 52  0.104592    0.759259  4.442233
# 53  0.104592    0.611940  4.442233
# 62  0.102041    0.740741  5.584046
# 63  0.102041    0.769231  5.584046
# 64  0.102041    0.800000  6.030769
# 65  0.102041    0.769231  6.030769
# 66  0.122449    0.888889  6.968889
# 67  0.122449    0.960000  6.968889
